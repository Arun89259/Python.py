# %%
# Print the result of 25 + 75.

print (25+75)
# Out:
# 100

# %%
# Print the result of 50 - 18.

print(50-18)
# Out:
# 32

# %%
# Create two variables a = 15 and b = 5. Print their sum.

a = 15
b = 5

print (a+b)
# Out:
# 20

# %%
# Create two variables and print division
x = 20
y = 4

print(x / y)
# Out:
# 5.0

# %%
# Calculate perimeter of rectangle
length = 10
width = 6
perimeter = 2 * (length + width)

print(perimeter)
# Out:
# 32

# %%
# Calculate total cost
Price = 250
Quantity = 3
Total = Price * Quantity

print(Total)
# Out:
# 750

# %%
# This program calculates square of 12
number = 12
square = 12 * 12

print(square)
# Out:
# 144

# %%
"""
Hello
This is a multi-line comment
Bye
"""

print("Hello")
# Out:
# Hello

# %%
# Print personal details in paragraph

print("My name is Arun Gupta. My hobby is coding. My weight is 65 kg. I have 1 siblings.")
# Out:
# My name is Arun Gupta. My hobby is coding. My weight is 65 kg. I have 1 siblings.

# %%
# Check output of expressions

print(2 + 3 * 4)      # Output: 14
print((2 + 3) * 4)    # Output: 20
# Out:
# 14
# 20
